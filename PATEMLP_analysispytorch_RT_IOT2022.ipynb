# %% [markdown]
# # Differential Privacy for RT_iot Dataset
# *Project Background:* <br>
# We, as a student, has a labeled private dataset and an unlabeled public dataset. We would like to collaberate with certain number of teachers to label our public dataset by training their similar datasets. In order to protect the data privacy of the teachers, we agree to add global noise to the labels they return for the public dataset. Then we label our public dataset based on the labels that most teachers agree. We combine the new labels with the public dataset and train with our private dataset. <br>
#
# *PATE analysis* is performed on teachers' predictions and the new labels with certain level of epsilon indicating how much information leakage is allowed.

# %%
# # # install syft package to use Private Aggregation of Teacher Ensembles (PATE)
# %%capture
# !pip install syft

# %%
# import necessary packages
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import torch
from torchvision import datasets, transforms
from torch.utils.data import Subset, TensorDataset
from torch.utils.data.dataset import random_split
from torch import nn, optim
import torch.nn.functional as F
# from syft.frameworks.torch.differential_privacy import pate
# import syft as sy
import matplotlib.pyplot as plt

import os
import time
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.utils import resample, shuffle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.metrics import confusion_matrix, precision_recall_curve, auc
from sklearn.metrics import (
    recall_score,
    f1_score,
    precision_score,
    accuracy_score,
    confusion_matrix,
    precision_recall_curve,
    average_precision_score,
     auc,
)
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from torch.utils.data import Dataset, DataLoader
from imblearn.over_sampling import RandomOverSampler

#Filtering errors
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# ### Section 1: Download and load rt_IOt dataset
#
# > Add blockquote
#
#
#
# *   **Trainset**: divide among teachers without overlapping
# *   **Testset**: split into private(labeled) and public(unlabeled) datasets; use models trained by teachers to label public dataset and train with the private dataset

# %%
from google.colab import drive
drive.mount('/content/drive')

data  = pd.read_csv('/content/drive/MyDrive/RT_IOT2022.csv', index_col = 0)
target_column = 'Attack_type'
data = data[data[target_column].isin(['DOS_SYN_Hping','Thing_Speak','ARP_poisioning'])]
num_classes = data[target_column].nunique()

# Add Upsampling
# Separate features and target
X = data.drop(columns=[target_column])
y = data[target_column]

# Perform upsampling (for synthetic minority over sampling() smote)
oversampler = RandomOverSampler(random_state=42)
X_resampled, y_resampled = oversampler.fit_resample(X, y)
# put it in one area rebuild dataset
data = pd.concat([X_resampled, y_resampled], axis=1)

# Label encode the target column(convert text to numbers)
from sklearn.preprocessing import LabelEncoder

# Instantiate LabelEncoder
label_encoder = LabelEncoder()

# Encode the target column
data[target_column] = label_encoder.fit_transform(data[target_column])

# Identify non-numeric columns (only two so dropping)
print(data.select_dtypes(include='object').columns)

data.drop(['proto', 'service'], axis=1, inplace=True)
# Out:
# Mounted at /content/drive
# Index(['proto', 'service'], dtype='object')

# %%
# Separate features and target
y = data[target_column].values
X = data.drop(columns=[target_column]).values  #

# Normalize the data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# Define a custom dataset
class TabularDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.tensor(features, dtype=torch.float32)
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __len__(self):
        return len(self.features)

    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]


# Create datasets
trainset = TabularDataset(X_train, y_train)
testset = TabularDataset(X_test, y_test)

# Data loaders
train_loader = DataLoader(trainset, batch_size=32, shuffle=True)
test_loader = DataLoader(testset, batch_size=32, shuffle=False)

# %%
# training and test data info
print('num training data: {0}'.format(len(trainset)))
print('num test data: {0}'.format(len(testset)))
# Out:
# num training data: 241380
# num test data: 42597

# %% [markdown]
# ### Section 2: Functions
#
#
# *   `teacher_data_allocator`: evenly allocate training dataset to the number of teachers as their private datasets
# *   `private_public_allocator`: split test dataset as the student's private dataset and public dataset
# *   `train`: model training with training and valid datasets
# *   `get_label_testset`: get labels of the student's public dataset from all teachers
# *   `add_global_noise`: add global noise to the labels that most teachers agree
# *   `create_labeled_public_db`: extract images from the public dataset and combine these images with the new labels; create a new dataloader for this new dataset

# %%
# divide unique training datasets among teachers
# split each dataset into training and valid sets
def teacher_data_allocator(trainset, batch_size=64, num_teachers=10, valid_train_split=0.3):
  data_per_teacher = len(trainset) // num_teachers    # round to the nearest integer
  train_loaders = []
  valid_loaders = []
  for i in range(num_teachers):
    if i == num_teachers - 1:
      ind = list(range(i * data_per_teacher, len(trainset)))
    else:
      ind = list(range(i * data_per_teacher, (i + 1) * data_per_teacher))
    data = Subset(trainset, ind)
    split = int(valid_train_split * len(data))
    valid_data, train_data = random_split(data, [split, len(data) - split])
    train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
    valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=batch_size, shuffle=False)
    train_loaders.append(train_loader)
    valid_loaders.append(valid_loader)
  return train_loaders, valid_loaders

# %%
# divide testset into private and public
def private_public_allocator(dataset, batch_size=64, split=0.7):
  split_ind = int(len(dataset) * split)

  # validset and testset
  # validset is smaller because dataset of each teacher is small
  private_ind = list(range(0, split_ind))
  public_ind = list(range(split_ind, len(dataset)))
  private_set = Subset(dataset, private_ind)
  public_set = Subset(dataset, public_ind)

  # validloader and testloader
  private_loader = torch.utils.data.DataLoader(private_set, batch_size=batch_size, shuffle=True)
  public_loader = torch.utils.data.DataLoader(public_set, batch_size=batch_size, shuffle=False)
  return private_loader, public_loader

# %%
def train(model, criterion, optimizer, trainloader, validloader, epochs=30, patience=3, plot=False):
    model = model
    criterion = criterion
    optimizer = optimizer
    epochs = epochs

    train_losses, valid_losses = [], []
    train_accuracies, valid_accuracies = [], []

    # Early stopping variables
    best_valid_loss = float('inf')
    epochs_no_improve = 0
    early_stop = False

    for e in range(epochs):
        if early_stop:
            print("Early stopping triggered")
            break

        running_loss = 0
        correct_train = 0
        total_train = 0

        # Training loop
        model.train()
        for inputs, labels in trainloader:
            optimizer.zero_grad()

            log_ps = model(inputs)
            loss = criterion(log_ps, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            # Track accuracy for training
            ps = torch.exp(log_ps)
            top_p, top_class = ps.topk(1, dim=1)
            equals = top_class == labels.view(*top_class.shape)
            correct_train += equals.sum().item()
            total_train += labels.size(0)

        # Validation loop
        valid_loss = 0
        correct_val = 0
        total_val = 0
        with torch.no_grad():
            model.eval()
            for inputs, labels in validloader:
                log_ps = model(inputs)
                valid_loss += criterion(log_ps, labels).item()

                ps = torch.exp(log_ps)
                top_p, top_class = ps.topk(1, dim=1)
                equals = top_class == labels.view(*top_class.shape)
                correct_val += equals.sum().item()
                total_val += labels.size(0)

        # Calculate average losses and accuracies
        train_losses.append(running_loss / len(trainloader))
        valid_losses.append(valid_loss / len(validloader))
        train_accuracies.append(correct_train / total_train)
        valid_accuracies.append(correct_val / total_val)

        # Print progress
        print(f"Epoch: {e+1}/{epochs}.. "
              f"Training Loss: {running_loss / len(trainloader):.3f}.. "
              f"Validation Loss: {valid_loss / len(validloader):.3f}.. "
              f"Validation Accuracy: {correct_val / total_val:.3f}")

        # Early stopping check
        current_valid_loss = valid_loss / len(validloader)
        if current_valid_loss < best_valid_loss:
            best_valid_loss = current_valid_loss
            epochs_no_improve = 0  # Reset counter
            best_model_state = model.state_dict()  # Save best model
        else:
            epochs_no_improve += 1

        if epochs_no_improve >= patience:
            print(f"Validation loss has not improved for {patience} epochs. Stopping early.")
            early_stop = True

    # Load the best model state before returning
    model.load_state_dict(best_model_state)

    if plot:
        return model, train_losses, valid_losses, train_accuracies, valid_accuracies
    else:
        return model

# %%
# label testset by models
def get_label_testset(models, testloader):
  test_labels = []
  for model in models:
    test_label = []
    for inputs, _ in testloader:
      with torch.no_grad():
        log_ps = model(inputs)
        ps = torch.exp(log_ps)
      top_p, top_class = ps.topk(1, dim=1)
      test_label.append(top_class.squeeze().tolist())
    test_label = sum(test_label, [])
    test_labels.append(test_label)
  return test_labels

# %%
# get predictions with global noise
#This function is designed to add noise to a set of predicted labels,
#enhancing privacy. It does this by taking a list of predictions (preds)
#and adding random noise drawn from a Laplace distribution to the vote counts for each possible label.
def add_global_noise(preds, epsilon=0.1):
  labels_with_noise = []
  for pred in preds:    # go thru entries
    label_counts = np.bincount(pred, minlength=preds.shape[1])

    epsilon = epsilon
    beta = 1 / epsilon

    for i in range(len(label_counts)):
      label_counts[i] += np.random.laplace(0, beta, 1)

    new_label = np.argmax(label_counts) % num_classes
    labels_with_noise.append(new_label)
  return np.array(labels_with_noise)

# %%
# create a new dataloader for the public dataset
# using the new labels added global noise
def create_labeled_public_db(dataloader, labels, batch_size=64):
  image_list = []
  for image, _ in dataloader:
    image_list.append(image)
  data = np.vstack(image_list)
  new_dataloader = list(zip(data, labels))
  new_dataloader = torch.utils.data.DataLoader(new_dataloader, shuffle=False, batch_size=batch_size)
  return new_dataloader

# %% [markdown]
# ### Section 3: Define neural network model structure

# %%
import torch.nn as nn
import torch.nn.functional as F

best_hp = {
'units_1': 128,
'dropout_1': 0.35,
'num_layers': 4,
'dropout_0': 0.3,
'learning_rate': 0.0001,
'optimizer': 'adam',
'dropout_2': 0.1,
'dropout_3': 0.25,
'dropout_4': 0.4,
}

input_size = X_train.shape[1]

# Classifier for tabular data
class Classifier(nn.Module):
    def __init__(self):
        super().__init__()

        # Define layers with hyperparameters from best_hp
        self.fc1 = nn.Linear(input_size, best_hp['units_1'])
        self.fc2 = nn.Linear(best_hp['units_1'], 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, num_classes)

        # Dropout layers with hyperparameters from best_hp
        self.dropout0 = nn.Dropout(p=best_hp['dropout_0'])
        self.dropout1 = nn.Dropout(p=best_hp['dropout_1'])
        self.dropout2 = nn.Dropout(p=best_hp['dropout_2'])
        self.dropout3 = nn.Dropout(p=best_hp['dropout_3'])
        self.dropout4 = nn.Dropout(p=best_hp['dropout_4'])

    def forward(self, x):
        # Applying forward pass with respective dropout layers
        x = self.dropout0(F.relu(self.fc1(x)))
        x = self.dropout1(F.relu(self.fc2(x)))
        x = self.dropout2(F.relu(self.fc3(x)))
        x = self.dropout3(self.fc4(x))
        x = F.log_softmax(self.dropout4(x), dim=1)

        return x

# %% [markdown]
# ### Section 4: Model training and PATE analysis
# We first ask the teachers to train their data and use these models to label the student's public data. After adding the global noise to create the new labels for the public dataset, the student then trains his/her private (training set) and public (valid set) data. PATE analysis returns independent and dependent epsilons show how much information has been leaked and how much teachers agree with each other.

# %%
# allocate training dataset to teachers
# split each of these datasets into training and valid datasets
teachers_train, teachers_valid = teacher_data_allocator(trainset)
print(len(teachers_train))
print(len(teachers_valid))
# Out:
# 10
# 10

# %%
# allocate test dataset to the student
# split the dataset into private and public datasets
private_loader, public_loader = private_public_allocator(testset)
print(len(private_loader))
print(len(public_loader))
# Out:
# 466
# 200

# %%
# get models trained by each teacher
teacher_models = []
for teacher_train, teacher_valid in zip(teachers_train, teachers_valid):
  model = Classifier()
  criterion = nn.NLLLoss()
  optimizer = optim.Adam(model.parameters(), lr=0.0001) #Adam opt
  teacher_model = train(model, criterion, optimizer, teacher_train, teacher_valid)
  teacher_models.append(teacher_model)
# Out:
# Epoch: 1/30.. Training Loss: 0.941.. Validation Loss: 0.575.. Validation Accuracy: 0.790
# Epoch: 2/30.. Training Loss: 0.651.. Validation Loss: 0.355.. Validation Accuracy: 0.896
# Epoch: 3/30.. Training Loss: 0.587.. Validation Loss: 0.283.. Validation Accuracy: 0.904
# Epoch: 4/30.. Training Loss: 0.555.. Validation Loss: 0.242.. Validation Accuracy: 0.912
# Epoch: 5/30.. Training Loss: 0.548.. Validation Loss: 0.216.. Validation Accuracy: 0.921
# Epoch: 6/30.. Training Loss: 0.530.. Validation Loss: 0.200.. Validation Accuracy: 0.923
# Epoch: 7/30.. Training Loss: 0.512.. Validation Loss: 0.183.. Validation Accuracy: 0.923
# Epoch: 8/30.. Training Loss: 0.505.. Validation Loss: 0.170.. Validation Accuracy: 0.924
# Epoch: 9/30.. Training Loss: 0.496.. Validation Loss: 0.158.. Validation Accuracy: 0.949
# Epoch: 10/30.. Training Loss: 0.485.. Validation Loss: 0.147.. Validation Accuracy: 0.950
# Epoch: 11/30.. Training Loss: 0.482.. Validation Loss: 0.138.. Validation Accuracy: 0.956
# Epoch: 12/30.. Training Loss: 0.471.. Validation Loss: 0.128.. Validation Accuracy: 0.963
# Epoch: 13/30.. Training Loss: 0.470.. Validation Loss: 0.123.. Validation Accuracy: 0.964
# Epoch: 14/30.. Training Loss: 0.460.. Validation Loss: 0.114.. Validation Accuracy: 0.967
# Epoch: 15/30.. Training Loss: 0.454.. Validation Loss: 0.107.. Validation Accuracy: 0.969
# Epoch: 16/30.. Training Loss: 0.455.. Validation Loss: 0.104.. Validation Accuracy: 0.969
# Epoch: 17/30.. Training Loss: 0.454.. Validation Loss: 0.098.. Validation Accuracy: 0.971
# Epoch: 18/30.. Training Loss: 0.450.. Validation Loss: 0.093.. Validation Accuracy: 0.972
# Epoch: 19/30.. Training Loss: 0.444.. Validation Loss: 0.089.. Validation Accuracy: 0.973
# Epoch: 20/30.. Training Loss: 0.437.. Validation Loss: 0.086.. Validation Accuracy: 0.973
# Epoch: 21/30.. Training Loss: 0.435.. Validation Loss: 0.083.. Validation Accuracy: 0.975
# Epoch: 22/30.. Training Loss: 0.438.. Validation Loss: 0.082.. Validation Accuracy: 0.974
# Epoch: 23/30.. Training Loss: 0.438.. Validation Loss: 0.079.. Validation Accuracy: 0.977
# Epoch: 24/30.. Training Loss: 0.437.. Validation Loss: 0.076.. Validation Accuracy: 0.975
# Epoch: 25/30.. Training Loss: 0.429.. Validation Loss: 0.073.. Validation Accuracy: 0.977
# Epoch: 26/30.. Training Loss: 0.429.. Validation Loss: 0.073.. Validation Accuracy: 0.976
# Epoch: 27/30.. Training Loss: 0.426.. Validation Loss: 0.068.. Validation Accuracy: 0.977
# Epoch: 28/30.. Training Loss: 0.427.. Validation Loss: 0.066.. Validation Accuracy: 0.977
# Epoch: 29/30.. Training Loss: 0.427.. Validation Loss: 0.064.. Validation Accuracy: 0.978
# Epoch: 30/30.. Training Loss: 0.426.. Validation Loss: 0.064.. Validation Accuracy: 0.979
# Epoch: 1/30.. Training Loss: 0.936.. Validation Loss: 0.564.. Validation Accuracy: 0.788
# Epoch: 2/30.. Training Loss: 0.670.. Validation Loss: 0.361.. Validation Accuracy: 0.909
# Epoch: 3/30.. Training Loss: 0.601.. Validation Loss: 0.281.. Validation Accuracy: 0.918
# Epoch: 4/30.. Training Loss: 0.563.. Validation Loss: 0.233.. Validation Accuracy: 0.921
# Epoch: 5/30.. Training Loss: 0.539.. Validation Loss: 0.199.. Validation Accuracy: 0.929
# Epoch: 6/30.. Training Loss: 0.521.. Validation Loss: 0.178.. Validation Accuracy: 0.930
# Epoch: 7/30.. Training Loss: 0.522.. Validation Loss: 0.166.. Validation Accuracy: 0.956
# Epoch: 8/30.. Training Loss: 0.503.. Validation Loss: 0.152.. Validation Accuracy: 0.959
# Epoch: 9/30.. Training Loss: 0.495.. Validation Loss: 0.139.. Validation Accuracy: 0.964
# Epoch: 10/30.. Training Loss: 0.479.. Validation Loss: 0.128.. Validation Accuracy: 0.970
# Epoch: 11/30.. Training Loss: 0.477.. Validation Loss: 0.116.. Validation Accuracy: 0.970
# Epoch: 12/30.. Training Loss: 0.471.. Validation Loss: 0.109.. Validation Accuracy: 0.975
# Epoch: 13/30.. Training Loss: 0.461.. Validation Loss: 0.107.. Validation Accuracy: 0.973
# Epoch: 14/30.. Training Loss: 0.461.. Validation Loss: 0.101.. Validation Accuracy: 0.975
# Epoch: 15/30.. Training Loss: 0.452.. Validation Loss: 0.092.. Validation Accuracy: 0.979
# Epoch: 16/30.. Training Loss: 0.455.. Validation Loss: 0.086.. Validation Accuracy: 0.979
# Epoch: 17/30.. Training Loss: 0.443.. Validation Loss: 0.081.. Validation Accuracy: 0.980
# Epoch: 18/30.. Training Loss: 0.450.. Validation Loss: 0.081.. Validation Accuracy: 0.980
# Epoch: 19/30.. Training Loss: 0.447.. Validation Loss: 0.073.. Validation Accuracy: 0.980
# Epoch: 20/30.. Training Loss: 0.439.. Validation Loss: 0.072.. Validation Accuracy: 0.982
# Epoch: 21/30.. Training Loss: 0.438.. Validation Loss: 0.069.. Validation Accuracy: 0.982
# Epoch: 22/30.. Training Loss: 0.439.. Validation Loss: 0.065.. Validation Accuracy: 0.982
# Epoch: 23/30.. Training Loss: 0.434.. Validation Loss: 0.063.. Validation Accuracy: 0.983
# Epoch: 24/30.. Training Loss: 0.429.. Validation Loss: 0.064.. Validation Accuracy: 0.983
# Epoch: 25/30.. Training Loss: 0.426.. Validation Loss: 0.063.. Validation Accuracy: 0.982
# Epoch: 26/30.. Training Loss: 0.428.. Validation Loss: 0.060.. Validation Accuracy: 0.983
# Epoch: 27/30.. Training Loss: 0.429.. Validation Loss: 0.059.. Validation Accuracy: 0.983
# Epoch: 28/30.. Training Loss: 0.429.. Validation Loss: 0.057.. Validation Accuracy: 0.983
# Epoch: 29/30.. Training Loss: 0.431.. Validation Loss: 0.056.. Validation Accuracy: 0.984
# Epoch: 30/30.. Training Loss: 0.416.. Validation Loss: 0.055.. Validation Accuracy: 0.984
# Epoch: 1/30.. Training Loss: 0.938.. Validation Loss: 0.569.. Validation Accuracy: 0.784
# Epoch: 2/30.. Training Loss: 0.680.. Validation Loss: 0.363.. Validation Accuracy: 0.892
# Epoch: 3/30.. Training Loss: 0.612.. Validation Loss: 0.286.. Validation Accuracy: 0.917
# Epoch: 4/30.. Training Loss: 0.569.. Validation Loss: 0.245.. Validation Accuracy: 0.917
# Epoch: 5/30.. Training Loss: 0.556.. Validation Loss: 0.219.. Validation Accuracy: 0.923
# Epoch: 6/30.. Training Loss: 0.538.. Validation Loss: 0.198.. Validation Accuracy: 0.924
# Epoch: 7/30.. Training Loss: 0.517.. Validation Loss: 0.177.. Validation Accuracy: 0.926
# Epoch: 8/30.. Training Loss: 0.508.. Validation Loss: 0.165.. Validation Accuracy: 0.945
# Epoch: 9/30.. Training Loss: 0.504.. Validation Loss: 0.160.. Validation Accuracy: 0.958
# Epoch: 10/30.. Training Loss: 0.494.. Validation Loss: 0.146.. Validation Accuracy: 0.949
# Epoch: 11/30.. Training Loss: 0.487.. Validation Loss: 0.136.. Validation Accuracy: 0.961
# Epoch: 12/30.. Training Loss: 0.479.. Validation Loss: 0.130.. Validation Accuracy: 0.962
# Epoch: 13/30.. Training Loss: 0.466.. Validation Loss: 0.122.. Validation Accuracy: 0.964
# Epoch: 14/30.. Training Loss: 0.470.. Validation Loss: 0.114.. Validation Accuracy: 0.967
# Epoch: 15/30.. Training Loss: 0.458.. Validation Loss: 0.107.. Validation Accuracy: 0.974
# Epoch: 16/30.. Training Loss: 0.462.. Validation Loss: 0.102.. Validation Accuracy: 0.973
# Epoch: 17/30.. Training Loss: 0.454.. Validation Loss: 0.099.. Validation Accuracy: 0.976
# Epoch: 18/30.. Training Loss: 0.455.. Validation Loss: 0.095.. Validation Accuracy: 0.976
# Epoch: 19/30.. Training Loss: 0.455.. Validation Loss: 0.092.. Validation Accuracy: 0.977
# Epoch: 20/30.. Training Loss: 0.449.. Validation Loss: 0.089.. Validation Accuracy: 0.977
# Epoch: 21/30.. Training Loss: 0.449.. Validation Loss: 0.087.. Validation Accuracy: 0.977
# Epoch: 22/30.. Training Loss: 0.439.. Validation Loss: 0.084.. Validation Accuracy: 0.978
# Epoch: 23/30.. Training Loss: 0.440.. Validation Loss: 0.081.. Validation Accuracy: 0.978
# Epoch: 24/30.. Training Loss: 0.440.. Validation Loss: 0.079.. Validation Accuracy: 0.979
# Epoch: 25/30.. Training Loss: 0.445.. Validation Loss: 0.078.. Validation Accuracy: 0.979
# Epoch: 26/30.. Training Loss: 0.439.. Validation Loss: 0.076.. Validation Accuracy: 0.980
# Epoch: 27/30.. Training Loss: 0.434.. Validation Loss: 0.075.. Validation Accuracy: 0.980
# Epoch: 28/30.. Training Loss: 0.432.. Validation Loss: 0.072.. Validation Accuracy: 0.980
# Epoch: 29/30.. Training Loss: 0.433.. Validation Loss: 0.071.. Validation Accuracy: 0.980
# Epoch: 30/30.. Training Loss: 0.436.. Validation Loss: 0.069.. Validation Accuracy: 0.981
# Epoch: 1/30.. Training Loss: 0.909.. Validation Loss: 0.542.. Validation Accuracy: 0.782
# Epoch: 2/30.. Training Loss: 0.662.. Validation Loss: 0.354.. Validation Accuracy: 0.897
# Epoch: 3/30.. Training Loss: 0.598.. Validation Loss: 0.282.. Validation Accuracy: 0.919
# Epoch: 4/30.. Training Loss: 0.559.. Validation Loss: 0.244.. Validation Accuracy: 0.918
# Epoch: 5/30.. Training Loss: 0.546.. Validation Loss: 0.215.. Validation Accuracy: 0.923
# Epoch: 6/30.. Training Loss: 0.522.. Validation Loss: 0.194.. Validation Accuracy: 0.926
# Epoch: 7/30.. Training Loss: 0.512.. Validation Loss: 0.184.. Validation Accuracy: 0.944
# Epoch: 8/30.. Training Loss: 0.498.. Validation Loss: 0.165.. Validation Accuracy: 0.930
# Epoch: 9/30.. Training Loss: 0.493.. Validation Loss: 0.154.. Validation Accuracy: 0.951
# Epoch: 10/30.. Training Loss: 0.476.. Validation Loss: 0.144.. Validation Accuracy: 0.955
# Epoch: 11/30.. Training Loss: 0.480.. Validation Loss: 0.134.. Validation Accuracy: 0.957
# Epoch: 12/30.. Training Loss: 0.472.. Validation Loss: 0.126.. Validation Accuracy: 0.960
# Epoch: 13/30.. Training Loss: 0.472.. Validation Loss: 0.121.. Validation Accuracy: 0.963
# Epoch: 14/30.. Training Loss: 0.465.. Validation Loss: 0.114.. Validation Accuracy: 0.965
# Epoch: 15/30.. Training Loss: 0.454.. Validation Loss: 0.106.. Validation Accuracy: 0.967
# Epoch: 16/30.. Training Loss: 0.449.. Validation Loss: 0.098.. Validation Accuracy: 0.972
# Epoch: 17/30.. Training Loss: 0.452.. Validation Loss: 0.096.. Validation Accuracy: 0.970
# Epoch: 18/30.. Training Loss: 0.452.. Validation Loss: 0.091.. Validation Accuracy: 0.975
# Epoch: 19/30.. Training Loss: 0.439.. Validation Loss: 0.087.. Validation Accuracy: 0.975
# Epoch: 20/30.. Training Loss: 0.438.. Validation Loss: 0.083.. Validation Accuracy: 0.977
# Epoch: 21/30.. Training Loss: 0.432.. Validation Loss: 0.079.. Validation Accuracy: 0.977
# Epoch: 22/30.. Training Loss: 0.437.. Validation Loss: 0.078.. Validation Accuracy: 0.977
# Epoch: 23/30.. Training Loss: 0.439.. Validation Loss: 0.075.. Validation Accuracy: 0.979
# Epoch: 24/30.. Training Loss: 0.442.. Validation Loss: 0.071.. Validation Accuracy: 0.979
# Epoch: 25/30.. Training Loss: 0.423.. Validation Loss: 0.068.. Validation Accuracy: 0.979
# Epoch: 26/30.. Training Loss: 0.427.. Validation Loss: 0.068.. Validation Accuracy: 0.978
# Epoch: 27/30.. Training Loss: 0.428.. Validation Loss: 0.067.. Validation Accuracy: 0.979
# Epoch: 28/30.. Training Loss: 0.428.. Validation Loss: 0.065.. Validation Accuracy: 0.979
# Epoch: 29/30.. Training Loss: 0.426.. Validation Loss: 0.064.. Validation Accuracy: 0.979
# Epoch: 30/30.. Training Loss: 0.425.. Validation Loss: 0.063.. Validation Accuracy: 0.977
# Epoch: 1/30.. Training Loss: 0.918.. Validation Loss: 0.536.. Validation Accuracy: 0.896
# Epoch: 2/30.. Training Loss: 0.654.. Validation Loss: 0.358.. Validation Accuracy: 0.887
# Epoch: 3/30.. Training Loss: 0.589.. Validation Loss: 0.286.. Validation Accuracy: 0.902
# Epoch: 4/30.. Training Loss: 0.561.. Validation Loss: 0.244.. Validation Accuracy: 0.912
# Epoch: 5/30.. Training Loss: 0.533.. Validation Loss: 0.217.. Validation Accuracy: 0.920
# Epoch: 6/30.. Training Loss: 0.524.. Validation Loss: 0.194.. Validation Accuracy: 0.917
# Epoch: 7/30.. Training Loss: 0.509.. Validation Loss: 0.176.. Validation Accuracy: 0.920
# Epoch: 8/30.. Training Loss: 0.503.. Validation Loss: 0.163.. Validation Accuracy: 0.950
# Epoch: 9/30.. Training Loss: 0.491.. Validation Loss: 0.151.. Validation Accuracy: 0.954
# Epoch: 10/30.. Training Loss: 0.475.. Validation Loss: 0.142.. Validation Accuracy: 0.956
# Epoch: 11/30.. Training Loss: 0.470.. Validation Loss: 0.131.. Validation Accuracy: 0.960
# Epoch: 12/30.. Training Loss: 0.464.. Validation Loss: 0.121.. Validation Accuracy: 0.969
# Epoch: 13/30.. Training Loss: 0.464.. Validation Loss: 0.114.. Validation Accuracy: 0.969
# Epoch: 14/30.. Training Loss: 0.455.. Validation Loss: 0.107.. Validation Accuracy: 0.970
# Epoch: 15/30.. Training Loss: 0.455.. Validation Loss: 0.102.. Validation Accuracy: 0.970
# Epoch: 16/30.. Training Loss: 0.447.. Validation Loss: 0.099.. Validation Accuracy: 0.971
# Epoch: 17/30.. Training Loss: 0.451.. Validation Loss: 0.094.. Validation Accuracy: 0.971
# Epoch: 18/30.. Training Loss: 0.441.. Validation Loss: 0.089.. Validation Accuracy: 0.974
# Epoch: 19/30.. Training Loss: 0.441.. Validation Loss: 0.086.. Validation Accuracy: 0.975
# Epoch: 20/30.. Training Loss: 0.446.. Validation Loss: 0.086.. Validation Accuracy: 0.975
# Epoch: 21/30.. Training Loss: 0.444.. Validation Loss: 0.083.. Validation Accuracy: 0.977
# Epoch: 22/30.. Training Loss: 0.432.. Validation Loss: 0.081.. Validation Accuracy: 0.977
# Epoch: 23/30.. Training Loss: 0.429.. Validation Loss: 0.079.. Validation Accuracy: 0.977
# Epoch: 24/30.. Training Loss: 0.429.. Validation Loss: 0.077.. Validation Accuracy: 0.977
# Epoch: 25/30.. Training Loss: 0.435.. Validation Loss: 0.075.. Validation Accuracy: 0.977
# Epoch: 26/30.. Training Loss: 0.435.. Validation Loss: 0.075.. Validation Accuracy: 0.978
# Epoch: 27/30.. Training Loss: 0.430.. Validation Loss: 0.073.. Validation Accuracy: 0.977
# Epoch: 28/30.. Training Loss: 0.433.. Validation Loss: 0.071.. Validation Accuracy: 0.977
# Epoch: 29/30.. Training Loss: 0.428.. Validation Loss: 0.069.. Validation Accuracy: 0.978
# Epoch: 30/30.. Training Loss: 0.427.. Validation Loss: 0.067.. Validation Accuracy: 0.978
# Epoch: 1/30.. Training Loss: 0.936.. Validation Loss: 0.561.. Validation Accuracy: 0.793
# Epoch: 2/30.. Training Loss: 0.662.. Validation Loss: 0.340.. Validation Accuracy: 0.883
# Epoch: 3/30.. Training Loss: 0.593.. Validation Loss: 0.263.. Validation Accuracy: 0.917
# Epoch: 4/30.. Training Loss: 0.547.. Validation Loss: 0.223.. Validation Accuracy: 0.919
# Epoch: 5/30.. Training Loss: 0.531.. Validation Loss: 0.197.. Validation Accuracy: 0.924
# Epoch: 6/30.. Training Loss: 0.514.. Validation Loss: 0.180.. Validation Accuracy: 0.930
# Epoch: 7/30.. Training Loss: 0.507.. Validation Loss: 0.164.. Validation Accuracy: 0.930
# Epoch: 8/30.. Training Loss: 0.503.. Validation Loss: 0.155.. Validation Accuracy: 0.960
# Epoch: 9/30.. Training Loss: 0.495.. Validation Loss: 0.142.. Validation Accuracy: 0.958
# Epoch: 10/30.. Training Loss: 0.479.. Validation Loss: 0.129.. Validation Accuracy: 0.966
# Epoch: 11/30.. Training Loss: 0.469.. Validation Loss: 0.119.. Validation Accuracy: 0.970
# Epoch: 12/30.. Training Loss: 0.466.. Validation Loss: 0.110.. Validation Accuracy: 0.972
# Epoch: 13/30.. Training Loss: 0.458.. Validation Loss: 0.104.. Validation Accuracy: 0.973
# Epoch: 14/30.. Training Loss: 0.451.. Validation Loss: 0.095.. Validation Accuracy: 0.976
# Epoch: 15/30.. Training Loss: 0.454.. Validation Loss: 0.090.. Validation Accuracy: 0.979
# Epoch: 16/30.. Training Loss: 0.448.. Validation Loss: 0.089.. Validation Accuracy: 0.978
# Epoch: 17/30.. Training Loss: 0.436.. Validation Loss: 0.083.. Validation Accuracy: 0.978
# Epoch: 18/30.. Training Loss: 0.444.. Validation Loss: 0.078.. Validation Accuracy: 0.979
# Epoch: 19/30.. Training Loss: 0.433.. Validation Loss: 0.075.. Validation Accuracy: 0.981
# Epoch: 20/30.. Training Loss: 0.440.. Validation Loss: 0.073.. Validation Accuracy: 0.981
# Epoch: 21/30.. Training Loss: 0.426.. Validation Loss: 0.070.. Validation Accuracy: 0.982
# Epoch: 22/30.. Training Loss: 0.436.. Validation Loss: 0.069.. Validation Accuracy: 0.982
# Epoch: 23/30.. Training Loss: 0.435.. Validation Loss: 0.066.. Validation Accuracy: 0.982
# Epoch: 24/30.. Training Loss: 0.428.. Validation Loss: 0.064.. Validation Accuracy: 0.983
# Epoch: 25/30.. Training Loss: 0.421.. Validation Loss: 0.063.. Validation Accuracy: 0.983
# Epoch: 26/30.. Training Loss: 0.429.. Validation Loss: 0.061.. Validation Accuracy: 0.981
# Epoch: 27/30.. Training Loss: 0.426.. Validation Loss: 0.060.. Validation Accuracy: 0.983
# Epoch: 28/30.. Training Loss: 0.416.. Validation Loss: 0.058.. Validation Accuracy: 0.983
# Epoch: 29/30.. Training Loss: 0.430.. Validation Loss: 0.058.. Validation Accuracy: 0.984
# Epoch: 30/30.. Training Loss: 0.418.. Validation Loss: 0.058.. Validation Accuracy: 0.982
# Epoch: 1/30.. Training Loss: 0.915.. Validation Loss: 0.550.. Validation Accuracy: 0.794
# Epoch: 2/30.. Training Loss: 0.660.. Validation Loss: 0.352.. Validation Accuracy: 0.898
# Epoch: 3/30.. Training Loss: 0.590.. Validation Loss: 0.279.. Validation Accuracy: 0.910
# Epoch: 4/30.. Training Loss: 0.556.. Validation Loss: 0.238.. Validation Accuracy: 0.915
# Epoch: 5/30.. Training Loss: 0.541.. Validation Loss: 0.214.. Validation Accuracy: 0.924
# Epoch: 6/30.. Training Loss: 0.521.. Validation Loss: 0.196.. Validation Accuracy: 0.940
# Epoch: 7/30.. Training Loss: 0.513.. Validation Loss: 0.179.. Validation Accuracy: 0.931
# Epoch: 8/30.. Training Loss: 0.498.. Validation Loss: 0.164.. Validation Accuracy: 0.949
# Epoch: 9/30.. Training Loss: 0.496.. Validation Loss: 0.156.. Validation Accuracy: 0.956
# Epoch: 10/30.. Training Loss: 0.498.. Validation Loss: 0.145.. Validation Accuracy: 0.954
# Epoch: 11/30.. Training Loss: 0.481.. Validation Loss: 0.136.. Validation Accuracy: 0.959
# Epoch: 12/30.. Training Loss: 0.479.. Validation Loss: 0.128.. Validation Accuracy: 0.964
# Epoch: 13/30.. Training Loss: 0.467.. Validation Loss: 0.118.. Validation Accuracy: 0.970
# Epoch: 14/30.. Training Loss: 0.468.. Validation Loss: 0.113.. Validation Accuracy: 0.970
# Epoch: 15/30.. Training Loss: 0.455.. Validation Loss: 0.107.. Validation Accuracy: 0.973
# Epoch: 16/30.. Training Loss: 0.449.. Validation Loss: 0.100.. Validation Accuracy: 0.974
# Epoch: 17/30.. Training Loss: 0.453.. Validation Loss: 0.095.. Validation Accuracy: 0.976
# Epoch: 18/30.. Training Loss: 0.449.. Validation Loss: 0.093.. Validation Accuracy: 0.974
# Epoch: 19/30.. Training Loss: 0.445.. Validation Loss: 0.086.. Validation Accuracy: 0.978
# Epoch: 20/30.. Training Loss: 0.434.. Validation Loss: 0.083.. Validation Accuracy: 0.978
# Epoch: 21/30.. Training Loss: 0.432.. Validation Loss: 0.078.. Validation Accuracy: 0.979
# Epoch: 22/30.. Training Loss: 0.430.. Validation Loss: 0.079.. Validation Accuracy: 0.979
# Epoch: 23/30.. Training Loss: 0.432.. Validation Loss: 0.077.. Validation Accuracy: 0.979
# Epoch: 24/30.. Training Loss: 0.433.. Validation Loss: 0.073.. Validation Accuracy: 0.980
# Epoch: 25/30.. Training Loss: 0.433.. Validation Loss: 0.069.. Validation Accuracy: 0.980
# Epoch: 26/30.. Training Loss: 0.430.. Validation Loss: 0.068.. Validation Accuracy: 0.980
# Epoch: 27/30.. Training Loss: 0.428.. Validation Loss: 0.068.. Validation Accuracy: 0.980
# Epoch: 28/30.. Training Loss: 0.419.. Validation Loss: 0.068.. Validation Accuracy: 0.980
# Epoch: 29/30.. Training Loss: 0.424.. Validation Loss: 0.065.. Validation Accuracy: 0.980
# Epoch: 30/30.. Training Loss: 0.428.. Validation Loss: 0.064.. Validation Accuracy: 0.980
# Epoch: 1/30.. Training Loss: 0.959.. Validation Loss: 0.616.. Validation Accuracy: 0.794
# Epoch: 2/30.. Training Loss: 0.668.. Validation Loss: 0.354.. Validation Accuracy: 0.906
# Epoch: 3/30.. Training Loss: 0.582.. Validation Loss: 0.268.. Validation Accuracy: 0.915
# Epoch: 4/30.. Training Loss: 0.549.. Validation Loss: 0.226.. Validation Accuracy: 0.915
# Epoch: 5/30.. Training Loss: 0.535.. Validation Loss: 0.199.. Validation Accuracy: 0.925
# Epoch: 6/30.. Training Loss: 0.523.. Validation Loss: 0.180.. Validation Accuracy: 0.926
# Epoch: 7/30.. Training Loss: 0.500.. Validation Loss: 0.165.. Validation Accuracy: 0.952
# Epoch: 8/30.. Training Loss: 0.498.. Validation Loss: 0.152.. Validation Accuracy: 0.958
# Epoch: 9/30.. Training Loss: 0.488.. Validation Loss: 0.142.. Validation Accuracy: 0.960
# Epoch: 10/30.. Training Loss: 0.472.. Validation Loss: 0.129.. Validation Accuracy: 0.965
# Epoch: 11/30.. Training Loss: 0.472.. Validation Loss: 0.120.. Validation Accuracy: 0.965
# Epoch: 12/30.. Training Loss: 0.461.. Validation Loss: 0.116.. Validation Accuracy: 0.971
# Epoch: 13/30.. Training Loss: 0.462.. Validation Loss: 0.107.. Validation Accuracy: 0.972
# Epoch: 14/30.. Training Loss: 0.457.. Validation Loss: 0.104.. Validation Accuracy: 0.969
# Epoch: 15/30.. Training Loss: 0.456.. Validation Loss: 0.099.. Validation Accuracy: 0.972
# Epoch: 16/30.. Training Loss: 0.449.. Validation Loss: 0.095.. Validation Accuracy: 0.975
# Epoch: 17/30.. Training Loss: 0.443.. Validation Loss: 0.089.. Validation Accuracy: 0.977
# Epoch: 18/30.. Training Loss: 0.446.. Validation Loss: 0.086.. Validation Accuracy: 0.977
# Epoch: 19/30.. Training Loss: 0.441.. Validation Loss: 0.085.. Validation Accuracy: 0.976
# Epoch: 20/30.. Training Loss: 0.441.. Validation Loss: 0.079.. Validation Accuracy: 0.977
# Epoch: 21/30.. Training Loss: 0.433.. Validation Loss: 0.076.. Validation Accuracy: 0.978
# Epoch: 22/30.. Training Loss: 0.433.. Validation Loss: 0.074.. Validation Accuracy: 0.979
# Epoch: 23/30.. Training Loss: 0.439.. Validation Loss: 0.074.. Validation Accuracy: 0.980
# Epoch: 24/30.. Training Loss: 0.430.. Validation Loss: 0.068.. Validation Accuracy: 0.981
# Epoch: 25/30.. Training Loss: 0.425.. Validation Loss: 0.069.. Validation Accuracy: 0.981
# Epoch: 26/30.. Training Loss: 0.431.. Validation Loss: 0.066.. Validation Accuracy: 0.982
# Epoch: 27/30.. Training Loss: 0.426.. Validation Loss: 0.066.. Validation Accuracy: 0.981
# Epoch: 28/30.. Training Loss: 0.426.. Validation Loss: 0.060.. Validation Accuracy: 0.982
# Epoch: 29/30.. Training Loss: 0.427.. Validation Loss: 0.060.. Validation Accuracy: 0.983
# Epoch: 30/30.. Training Loss: 0.424.. Validation Loss: 0.063.. Validation Accuracy: 0.983
# Epoch: 1/30.. Training Loss: 0.910.. Validation Loss: 0.529.. Validation Accuracy: 0.794
# Epoch: 2/30.. Training Loss: 0.651.. Validation Loss: 0.333.. Validation Accuracy: 0.905
# Epoch: 3/30.. Training Loss: 0.584.. Validation Loss: 0.262.. Validation Accuracy: 0.916
# Epoch: 4/30.. Training Loss: 0.561.. Validation Loss: 0.224.. Validation Accuracy: 0.923
# Epoch: 5/30.. Training Loss: 0.540.. Validation Loss: 0.200.. Validation Accuracy: 0.928
# Epoch: 6/30.. Training Loss: 0.529.. Validation Loss: 0.180.. Validation Accuracy: 0.927
# Epoch: 7/30.. Training Loss: 0.508.. Validation Loss: 0.166.. Validation Accuracy: 0.928
# Epoch: 8/30.. Training Loss: 0.490.. Validation Loss: 0.154.. Validation Accuracy: 0.931
# Epoch: 9/30.. Training Loss: 0.486.. Validation Loss: 0.145.. Validation Accuracy: 0.955
# Epoch: 10/30.. Training Loss: 0.478.. Validation Loss: 0.136.. Validation Accuracy: 0.956
# Epoch: 11/30.. Training Loss: 0.476.. Validation Loss: 0.126.. Validation Accuracy: 0.958
# Epoch: 12/30.. Training Loss: 0.469.. Validation Loss: 0.119.. Validation Accuracy: 0.967
# Epoch: 13/30.. Training Loss: 0.470.. Validation Loss: 0.114.. Validation Accuracy: 0.967
# Epoch: 14/30.. Training Loss: 0.464.. Validation Loss: 0.106.. Validation Accuracy: 0.971
# Epoch: 15/30.. Training Loss: 0.455.. Validation Loss: 0.099.. Validation Accuracy: 0.974
# Epoch: 16/30.. Training Loss: 0.448.. Validation Loss: 0.095.. Validation Accuracy: 0.975
# Epoch: 17/30.. Training Loss: 0.447.. Validation Loss: 0.089.. Validation Accuracy: 0.977
# Epoch: 18/30.. Training Loss: 0.441.. Validation Loss: 0.087.. Validation Accuracy: 0.975
# Epoch: 19/30.. Training Loss: 0.438.. Validation Loss: 0.084.. Validation Accuracy: 0.976
# Epoch: 20/30.. Training Loss: 0.443.. Validation Loss: 0.082.. Validation Accuracy: 0.977
# Epoch: 21/30.. Training Loss: 0.444.. Validation Loss: 0.080.. Validation Accuracy: 0.978
# Epoch: 22/30.. Training Loss: 0.439.. Validation Loss: 0.076.. Validation Accuracy: 0.979
# Epoch: 23/30.. Training Loss: 0.439.. Validation Loss: 0.075.. Validation Accuracy: 0.979
# Epoch: 24/30.. Training Loss: 0.451.. Validation Loss: 0.073.. Validation Accuracy: 0.980
# Epoch: 25/30.. Training Loss: 0.425.. Validation Loss: 0.073.. Validation Accuracy: 0.979
# Epoch: 26/30.. Training Loss: 0.431.. Validation Loss: 0.069.. Validation Accuracy: 0.979
# Epoch: 27/30.. Training Loss: 0.419.. Validation Loss: 0.067.. Validation Accuracy: 0.981
# Epoch: 28/30.. Training Loss: 0.432.. Validation Loss: 0.065.. Validation Accuracy: 0.981
# Epoch: 29/30.. Training Loss: 0.428.. Validation Loss: 0.065.. Validation Accuracy: 0.981
# Epoch: 30/30.. Training Loss: 0.429.. Validation Loss: 0.062.. Validation Accuracy: 0.981
# Epoch: 1/30.. Training Loss: 0.943.. Validation Loss: 0.578.. Validation Accuracy: 0.790
# Epoch: 2/30.. Training Loss: 0.656.. Validation Loss: 0.343.. Validation Accuracy: 0.911
# Epoch: 3/30.. Training Loss: 0.599.. Validation Loss: 0.268.. Validation Accuracy: 0.924
# Epoch: 4/30.. Training Loss: 0.549.. Validation Loss: 0.218.. Validation Accuracy: 0.930
# Epoch: 5/30.. Training Loss: 0.538.. Validation Loss: 0.195.. Validation Accuracy: 0.927
# Epoch: 6/30.. Training Loss: 0.515.. Validation Loss: 0.175.. Validation Accuracy: 0.948
# Epoch: 7/30.. Training Loss: 0.510.. Validation Loss: 0.160.. Validation Accuracy: 0.931
# Epoch: 8/30.. Training Loss: 0.492.. Validation Loss: 0.147.. Validation Accuracy: 0.955
# Epoch: 9/30.. Training Loss: 0.481.. Validation Loss: 0.137.. Validation Accuracy: 0.958
# Epoch: 10/30.. Training Loss: 0.474.. Validation Loss: 0.130.. Validation Accuracy: 0.959
# Epoch: 11/30.. Training Loss: 0.473.. Validation Loss: 0.121.. Validation Accuracy: 0.964
# Epoch: 12/30.. Training Loss: 0.471.. Validation Loss: 0.114.. Validation Accuracy: 0.966
# Epoch: 13/30.. Training Loss: 0.459.. Validation Loss: 0.106.. Validation Accuracy: 0.969
# Epoch: 14/30.. Training Loss: 0.451.. Validation Loss: 0.101.. Validation Accuracy: 0.972
# Epoch: 15/30.. Training Loss: 0.461.. Validation Loss: 0.095.. Validation Accuracy: 0.972
# Epoch: 16/30.. Training Loss: 0.448.. Validation Loss: 0.091.. Validation Accuracy: 0.974
# Epoch: 17/30.. Training Loss: 0.452.. Validation Loss: 0.088.. Validation Accuracy: 0.976
# Epoch: 18/30.. Training Loss: 0.443.. Validation Loss: 0.086.. Validation Accuracy: 0.975
# Epoch: 19/30.. Training Loss: 0.445.. Validation Loss: 0.082.. Validation Accuracy: 0.977
# Epoch: 20/30.. Training Loss: 0.441.. Validation Loss: 0.080.. Validation Accuracy: 0.977
# Epoch: 21/30.. Training Loss: 0.432.. Validation Loss: 0.076.. Validation Accuracy: 0.976
# Epoch: 22/30.. Training Loss: 0.436.. Validation Loss: 0.072.. Validation Accuracy: 0.977
# Epoch: 23/30.. Training Loss: 0.435.. Validation Loss: 0.073.. Validation Accuracy: 0.978
# Epoch: 24/30.. Training Loss: 0.429.. Validation Loss: 0.068.. Validation Accuracy: 0.980
# Epoch: 25/30.. Training Loss: 0.425.. Validation Loss: 0.067.. Validation Accuracy: 0.980
# Epoch: 26/30.. Training Loss: 0.432.. Validation Loss: 0.064.. Validation Accuracy: 0.981
# Epoch: 27/30.. Training Loss: 0.424.. Validation Loss: 0.063.. Validation Accuracy: 0.981
# Epoch: 28/30.. Training Loss: 0.425.. Validation Loss: 0.062.. Validation Accuracy: 0.981
# Epoch: 29/30.. Training Loss: 0.428.. Validation Loss: 0.061.. Validation Accuracy: 0.982
# Epoch: 30/30.. Training Loss: 0.418.. Validation Loss: 0.058.. Validation Accuracy: 0.982

# %%
# predict labels for testset from each teacher
# row = num of test data
# col = predictions from each teacher
preds = get_label_testset(teacher_models, public_loader)
preds = np.array([np.array(p) for p in preds]).transpose(1, 0)

# %%
preds_with_noise = add_global_noise(preds, epsilon=1.3)
len(preds_with_noise)
# Out:
# <ipython-input-10-f34d81c66f0e>:14: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label_counts[i] += np.random.laplace(0, beta, 1)
# 12780

# %%
# PATE Analysis manual(https://pysyftbenardi.readthedocs.io/en/sphinx_backup/api/syft/frameworks/torch/dp/pate/index.html)
teacher_preds = preds
noise_eps = 1.3  # Privacy noise epsilon (scale parameter of Laplace noise)
delta = 1e-5  # Privacy delta (used in the privacy guarantee)

# Compute max votes for each query
max_votes = np.max(teacher_preds, axis=0)  # Maximum votes for each query and most frequent
total_queries = teacher_preds.shape[1] #(holds totalqueries,counting total queries votes)

# Data-independent epsilon(number used for protection even if theres an outlier)
data_ind_eps = (1 / noise_eps) * np.max(max_votes)
print("Data-independent epsilon:", data_ind_eps)

# Data-dependent epsilon(highest you can go while still maintaining privacy)
total_votes = np.sum(teacher_preds, axis=0)
data_dep_eps = np.sum(
    np.log(1 + (total_queries * max_votes) / (noise_eps * total_votes))
)
print("Data-dependent epsilon:", data_dep_eps)
# Out:
# Data-independent epsilon: 1.5384615384615383
# Data-dependent epsilon: 0.012161131198220246

# %% [markdown]
# Note: data dependent epsilon is high when there is no strong agreement among teachers. Thus, the richness of information is shared with both general information and private information. data independent epsilon is high when PATE analysis is based on a high epsilon (e.g., epsilon=0.6).

# %%
# PATE analysis
# data_dep_eps, data_ind_eps = sy.pate.perform_analysis(teacher_preds=preds.T, indices=preds_with_noise, noise_eps=0.1, delta=1e-5)
# print('Data dependent epsilon:', data_dep_eps)
# print('Data independent epsilon:', data_ind_eps)

# %%
# create new dataloader for the public data
# using the original function
public_loader_labeled = create_labeled_public_db(public_loader, preds_with_noise)
len(public_loader_labeled)
# Out:
# 200

# %%
# train model using private and public datasets
my_model = Classifier()
criterion = nn.NLLLoss()
optimizer = optim.Adam(my_model.parameters(), lr=0.0001)

my_model, train_losses, valid_losses, train_accuracies, valid_accuracies = train(
    model=my_model,
    criterion=criterion,
    optimizer=optimizer,
    trainloader=private_loader,
    validloader=public_loader_labeled,
    epochs=30, plot = True
)
# Out:
# Epoch: 1/30.. Training Loss: 0.794.. Validation Loss: 0.371.. Validation Accuracy: 0.901
# Epoch: 2/30.. Training Loss: 0.590.. Validation Loss: 0.233.. Validation Accuracy: 0.920
# Epoch: 3/30.. Training Loss: 0.535.. Validation Loss: 0.174.. Validation Accuracy: 0.936
# Epoch: 4/30.. Training Loss: 0.510.. Validation Loss: 0.142.. Validation Accuracy: 0.941
# Epoch: 5/30.. Training Loss: 0.494.. Validation Loss: 0.121.. Validation Accuracy: 0.972
# Epoch: 6/30.. Training Loss: 0.484.. Validation Loss: 0.104.. Validation Accuracy: 0.979
# Epoch: 7/30.. Training Loss: 0.469.. Validation Loss: 0.085.. Validation Accuracy: 0.982
# Epoch: 8/30.. Training Loss: 0.462.. Validation Loss: 0.075.. Validation Accuracy: 0.988
# Epoch: 9/30.. Training Loss: 0.453.. Validation Loss: 0.062.. Validation Accuracy: 0.992
# Epoch: 10/30.. Training Loss: 0.454.. Validation Loss: 0.059.. Validation Accuracy: 0.991
# Epoch: 11/30.. Training Loss: 0.445.. Validation Loss: 0.051.. Validation Accuracy: 0.994
# Epoch: 12/30.. Training Loss: 0.439.. Validation Loss: 0.044.. Validation Accuracy: 0.996
# Epoch: 13/30.. Training Loss: 0.434.. Validation Loss: 0.038.. Validation Accuracy: 0.997
# Epoch: 14/30.. Training Loss: 0.428.. Validation Loss: 0.039.. Validation Accuracy: 0.997
# Epoch: 15/30.. Training Loss: 0.427.. Validation Loss: 0.039.. Validation Accuracy: 0.997
# Epoch: 16/30.. Training Loss: 0.420.. Validation Loss: 0.036.. Validation Accuracy: 0.997
# Epoch: 17/30.. Training Loss: 0.422.. Validation Loss: 0.033.. Validation Accuracy: 0.997
# Epoch: 18/30.. Training Loss: 0.417.. Validation Loss: 0.036.. Validation Accuracy: 0.995
# Epoch: 19/30.. Training Loss: 0.415.. Validation Loss: 0.032.. Validation Accuracy: 0.992
# Epoch: 20/30.. Training Loss: 0.415.. Validation Loss: 0.033.. Validation Accuracy: 0.995
# Epoch: 21/30.. Training Loss: 0.415.. Validation Loss: 0.033.. Validation Accuracy: 0.994
# Epoch: 22/30.. Training Loss: 0.419.. Validation Loss: 0.033.. Validation Accuracy: 0.992
# Validation loss has not improved for 3 epochs. Stopping early.
# Early stopping triggered

# %% [markdown]
# ## Student Plots

# %%
# Plotting the losses
plt.figure(figsize=(12, 5))

# Plot Training and Validation Losses
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_losses)+1), train_losses, label='Training Loss', color='blue')
plt.plot(range(1, len(valid_losses)+1), valid_losses, label='Validation Loss', color='red')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Training and Validation Accuracy
plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_accuracies)+1), train_accuracies, label='Training Accuracy', color='blue')
plt.plot(range(1, len(valid_accuracies)+1), valid_accuracies, label='Validation Accuracy', color='red')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
def generate_predictions(model, validloader):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in validloader:
            log_ps = model(inputs)
            ps = torch.exp(log_ps)
            top_p, top_class = ps.topk(1, dim=1)
            all_preds.extend(top_class.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    return np.array(all_preds), np.array(all_labels)

# Get predictions and true labels
all_preds, all_labels = generate_predictions(my_model, public_loader_labeled)

# Calculate F1 score
f1 = f1_score(all_labels, all_preds, average='macro')

# Print F1 score
print(f"F1 Score: {f1:.4f}")

# Generate confusion matrix
conf_matrix = confusion_matrix(all_labels, all_preds)

# Plot confusion matrix with class names
class_labels = label_encoder.classes_
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# F1 Score: 0.9923
